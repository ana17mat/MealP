# %%
import pandas as pd

# %%
veggie_db=pd.read_csv('veggie_db')

fish_db=pd.read_csv('fish_db')

meat_db=pd.read_csv('meat_db')

# %%
veggie_idset=set(veggie_db['id'])

fish_idset=set(fish_db['id'])

meat_idset=set(meat_db['id'])

# %%
veggie_idset
# Out:
# {52771, 52811, 52849, 52863, 52867, 52869, 52906, 52908, 53026, 53047}

# %%
veggie_idset
# Out:
# {52811, 52849, 52863, 52867, 52869, 52906, 52908, 53026, 53047}

# %%
import random

# %%
r=random.choice(list(veggie_idset))
veggie_idset=veggie_idset-{r}
print(r)
print(veggie_idset)
# Out:
# 52869
# {53026, 52867, 52771, 52906, 52811, 52908, 52849, 53047, 52863}

# %%
#lunch_recipes=[]

r=random.choice(list(veggie_idset))
veggie_idset=veggie_idset-{r}

# %%
lunch_recipes.append(r)

# %%
print(lunch_recipes)
# Out:
# [52771, 52811]

# %%
r
# Out:
# 53047

# %%
set_aldi=set()

# %%
set_aldi=set_aldi.union([2])

# %%
set_aldi
# Out:
# {2}

# %%
meat_db['ings'][]
# Out:
# 0    [465, 728, 731, 86, 182, 461, 287, 56, 382, 15...
# 1                    [727, 460, 531, 208, 88, 501, 85]
# 2                   [597, 86, 209, 727, 531, 287, 389]
# 3                                                  NaN
# 4                            [373, 511, 290, 113, 210]
# 5                   [242, 88, 351, 340, 601, 635, 737]
# 6                   [74, 179, 108, 114, 575, 373, 421]
# 7                [609, 460, 435, 212, 55, 85, 34, 731]
# 8                       [315, 114, 669, 138, 623, 162]
# 9                            [379, 653, 667, 315, 121]
# Name: ings, dtype: object

# %%
meat_db
# Out:
#    Unnamed: 0     id                                               ings  \
# 0           0  52796  [465, 728, 731, 86, 182, 461, 287, 56, 382, 15...
# 1           1  52806                  [727, 460, 531, 208, 88, 501, 85]
# 2           2  52814                 [597, 86, 209, 727, 531, 287, 389]
# 3           3  53039                                                NaN
# 4           4  52920                          [373, 511, 290, 113, 210]
# 5           5  52850                 [242, 88, 351, 340, 601, 635, 737]
# 6           6  52770                 [74, 179, 108, 114, 575, 373, 421]
# 7           7  52826              [609, 460, 435, 212, 55, 85, 34, 731]
# 8           8  52834                     [315, 114, 669, 138, 623, 162]
# 9           9  52803                          [379, 653, 667, 315, 121]
#
#                                      ings2                        name  \
# 0                                      NaN   Chicken Alfredo Primavera
# 1                                      NaN            Tandoori chicken
# 2                                      NaN            Thai Green Curry
# 3  [535, 460, 306, 372, 723, 85, 177, 708]  Piri-piri chicken and slaw
# 4                                      NaN             Chicken Marengo
# 5                                      NaN            Chicken Couscous
# 6                                      NaN         Spaghetti Bolognese
# 7                                      NaN         Braised Beef Chilli
# 8                                      NaN             Beef stroganoff
# 9                                      NaN             Beef Wellington
#
#                                                ingsM
# 0  ['Butter', 'Olive Oil', 'Chicken', 'Salt', 'Sq...
# 1  ['lemons', 'paprika', 'red onions', 'chicken t...
# 2  ['potatoes', 'green beans', 'sunflower oil', '...
# 3  ['Chicken', 'Red Chilli', 'Garlic', 'Ginger', ...
# 4  ['Olive Oil', 'Mushrooms', 'Chicken Legs', 'Pa...
# 5  ['Olive Oil', 'Onion', 'Chicken Breast', 'Ging...
# 6  ['onions', 'olive oil', 'garlic', 'lean minced...
# 7  ['Beef', 'Onions', 'Garlic', 'Olive oil', 'Cho...
# 8  ['Olive Oil', 'Onions', 'Garlic', 'Butter', 'M...
# 9  ['mushrooms', 'English Mustard', 'Olive Oil', ...

# %%
list(meat_db['id']).index(52814)
# Out:
# 2

# %%
meat_db['ings'][2]
# Out:
# '[597, 86, 209, 727, 531, 287, 389]'

# %%
aldi_db=pd.read_csv('aldi_db.csv')

# %%
aldi_db
# Out:
#      Unnamed: 0                                         Ingredient  Price
# 0             1   Rich & Creamy Melt In The Middle Salmon Fishc...   2.79
# 1             2   Smoked Mackerel Fillets - Peppered 200g The F...   1.49
# 2             3   Smoked Mackerel Fillets - Hot 200g The Fishmo...   1.49
# 3             4     Hot Smoked Salmon Fillets 185g The Fishmonger    3.49
# 4             5                               Salmon Fillets 185g    3.49
# ..          ...                                                ...    ...
# 743          38          Granny Smith Apples 6 Pack Nature's Pick    1.29
# 744          39   Spinach & Rocket / Spinach & Kale 120g Health...   1.29
# 745          40   Spinach & Rocket / Spinach & Kale 120g Health...   1.29
# 746          41                         Strawberries 250g Organic    2.49
# 747          42            Prepared Vegetables 500g Nature's Pick    1.25
#
# [748 rows x 3 columns]

# %%
aldi_db['Price'][3]
# Out:
# 3.49

# %%
fish_db
# Out:
#    Unnamed: 0     id                                     ings  \
# 0           0  52960            [17, 711, 720, 727, 109, 724]
# 1           1  53041         [66, 67, 460, 727, 85, 373, 339]
# 2           2  52946         [19, 421, 444, 316, 414, 34, 35]
# 3           3  52823          [336, 4, 26, 14, 115, 731, 465]
# 4           4  52773              [3, 10, 373, 380, 415, 105]
# 5           5  52777  [709, 81, 487, 490, 722, 723, 428, 291]
# 6           6  52819            [83, 727, 711, 177, 335, 451]
# 7           7  53040         [86, 316, 417, 34, 136, 26, 731]
# 8           8  52975           [727, 703, 720, 401, 723, 138]
# 9           9  52936    [12, 96, 315, 709, 373, 713, 36, 428]
#
#                                name  \
# 0              Salmon Avocado Salad
# 1       Grilled Portuguese sardines
# 2                    Kung Po Prawns
# 3              Salmon Prawn Risotto
# 4             Honey Teriyaki Salmon
# 5         Mediterranean Pasta Salad
# 6           Cajun spiced fish tacos
# 7  Spring onion and prawn empanadas
# 8                Tuna and Egg Briks
# 9                Saltfish and Ackee
#
#                                                ingsM
# 0  ['Salmon', 'Avocado', 'Cucumber', 'Spinach', '...
# 1  ['Sardines', 'Olive Oil', 'Garlic', 'Paprika',...
# 2  ['Prawns', 'Soy Sauce', 'Tomato Puree', 'Corn ...
# 3  ['butter', 'onion', 'rice', 'white wine', 'veg...
# 4  ['Salmon', 'Olive oil', 'Soy Sauce', 'Sake', '...
# 5  ['mozzarella balls', 'baby plum tomatoes', 'fr...
# 6  ['cajun', 'cayenne pepper', 'white fish', 'veg...
# 7  ['Spring Onions', 'Olive Oil', 'Red Chilli', '...
# 8  ['Olive Oil', 'Spring Onions', 'Spinach', 'Fil...
# 9  ['Salt Cod', 'Ackee', 'Onion', 'Paprika', 'Cur...

# %%
meat_db
# Out:
#    Unnamed: 0     id                                               ings  \
# 0           0  52796  [465, 728, 731, 86, 182, 461, 287, 56, 382, 15...
# 1           1  52806                  [727, 460, 531, 208, 88, 501, 85]
# 2           2  52814                 [597, 86, 209, 727, 531, 287, 389]
# 3           3  53039                                                NaN
# 4           4  52920                          [373, 511, 290, 113, 210]
# 5           5  52850                 [242, 88, 351, 340, 601, 635, 737]
# 6           6  52770                 [74, 179, 108, 114, 575, 373, 421]
# 7           7  52826              [609, 460, 435, 212, 55, 85, 34, 731]
# 8           8  52834                     [315, 114, 669, 138, 623, 162]
# 9           9  52803                          [379, 653, 667, 315, 121]
#
#                                      ings2                        name  \
# 0                                      NaN   Chicken Alfredo Primavera
# 1                                      NaN            Tandoori chicken
# 2                                      NaN            Thai Green Curry
# 3  [535, 460, 306, 372, 723, 85, 177, 708]  Piri-piri chicken and slaw
# 4                                      NaN             Chicken Marengo
# 5                                      NaN            Chicken Couscous
# 6                                      NaN         Spaghetti Bolognese
# 7                                      NaN         Braised Beef Chilli
# 8                                      NaN             Beef stroganoff
# 9                                      NaN             Beef Wellington
#
#                                                ingsM
# 0  ['Butter', 'Olive Oil', 'Chicken', 'Salt', 'Sq...
# 1  ['lemons', 'paprika', 'red onions', 'chicken t...
# 2  ['potatoes', 'green beans', 'sunflower oil', '...
# 3  ['Chicken', 'Red Chilli', 'Garlic', 'Ginger', ...
# 4  ['Olive Oil', 'Mushrooms', 'Chicken Legs', 'Pa...
# 5  ['Olive Oil', 'Onion', 'Chicken Breast', 'Ging...
# 6  ['onions', 'olive oil', 'garlic', 'lean minced...
# 7  ['Beef', 'Onions', 'Garlic', 'Olive oil', 'Cho...
# 8  ['Olive Oil', 'Onions', 'Garlic', 'Butter', 'M...
# 9  ['mushrooms', 'English Mustard', 'Olive Oil', ...

# %%
type(veggie_db['ings'][3][1])
# Out:
# str

# %%
aldi_db['Price'][3]
# Out:
# 3.49

# %%
meat_db['ings'][3]
# Out:
# nan

# %%
meat_db
# Out:
#    Unnamed: 0     id                                               ings  \
# 0           0  52796  [465, 728, 731, 86, 182, 461, 287, 56, 382, 15...
# 1           1  52806                  [727, 460, 531, 208, 88, 501, 85]
# 2           2  52814                 [597, 86, 209, 727, 531, 287, 389]
# 3           3  53039                                                NaN
# 4           4  52920                          [373, 511, 290, 113, 210]
# 5           5  52850                 [242, 88, 351, 340, 601, 635, 737]
# 6           6  52770                 [74, 179, 108, 114, 575, 373, 421]
# 7           7  52826              [609, 460, 435, 212, 55, 85, 34, 731]
# 8           8  52834                     [315, 114, 669, 138, 623, 162]
# 9           9  52803                          [379, 653, 667, 315, 121]
#
#                                      ings2                        name  \
# 0                                      NaN   Chicken Alfredo Primavera
# 1                                      NaN            Tandoori chicken
# 2                                      NaN            Thai Green Curry
# 3  [535, 460, 306, 372, 723, 85, 177, 708]  Piri-piri chicken and slaw
# 4                                      NaN             Chicken Marengo
# 5                                      NaN            Chicken Couscous
# 6                                      NaN         Spaghetti Bolognese
# 7                                      NaN         Braised Beef Chilli
# 8                                      NaN             Beef stroganoff
# 9                                      NaN             Beef Wellington
#
#                                                ingsM
# 0  ['Butter', 'Olive Oil', 'Chicken', 'Salt', 'Sq...
# 1  ['lemons', 'paprika', 'red onions', 'chicken t...
# 2  ['potatoes', 'green beans', 'sunflower oil', '...
# 3  ['Chicken', 'Red Chilli', 'Garlic', 'Ginger', ...
# 4  ['Olive Oil', 'Mushrooms', 'Chicken Legs', 'Pa...
# 5  ['Olive Oil', 'Onion', 'Chicken Breast', 'Ging...
# 6  ['onions', 'olive oil', 'garlic', 'lean minced...
# 7  ['Beef', 'Onions', 'Garlic', 'Olive oil', 'Cho...
# 8  ['Olive Oil', 'Onions', 'Garlic', 'Butter', 'M...
# 9  ['mushrooms', 'English Mustard', 'Olive Oil', ...

# %%
fish_db
# Out:
#    Unnamed: 0     id                                     ings  \
# 0           0  52960            [17, 711, 720, 727, 109, 724]
# 1           1  53041         [66, 67, 460, 727, 85, 373, 339]
# 2           2  52946         [19, 421, 444, 316, 414, 34, 35]
# 3           3  52823          [336, 4, 26, 14, 115, 731, 465]
# 4           4  52773              [3, 10, 373, 380, 415, 105]
# 5           5  52777  [709, 81, 487, 490, 722, 723, 428, 291]
# 6           6  52819            [83, 727, 711, 177, 335, 451]
# 7           7  53040         [86, 316, 417, 34, 136, 26, 731]
# 8           8  52975           [727, 703, 720, 401, 723, 138]
# 9           9  52936    [12, 96, 315, 709, 373, 713, 36, 428]
#
#                                name  \
# 0              Salmon Avocado Salad
# 1       Grilled Portuguese sardines
# 2                    Kung Po Prawns
# 3              Salmon Prawn Risotto
# 4             Honey Teriyaki Salmon
# 5         Mediterranean Pasta Salad
# 6           Cajun spiced fish tacos
# 7  Spring onion and prawn empanadas
# 8                Tuna and Egg Briks
# 9                Saltfish and Ackee
#
#                                                ingsM
# 0  ['Salmon', 'Avocado', 'Cucumber', 'Spinach', '...
# 1  ['Sardines', 'Olive Oil', 'Garlic', 'Paprika',...
# 2  ['Prawns', 'Soy Sauce', 'Tomato Puree', 'Corn ...
# 3  ['butter', 'onion', 'rice', 'white wine', 'veg...
# 4  ['Salmon', 'Olive oil', 'Soy Sauce', 'Sake', '...
# 5  ['mozzarella balls', 'baby plum tomatoes', 'fr...
# 6  ['cajun', 'cayenne pepper', 'white fish', 'veg...
# 7  ['Spring Onions', 'Olive Oil', 'Red Chilli', '...
# 8  ['Olive Oil', 'Spring Onions', 'Spinach', 'Fil...
# 9  ['Salt Cod', 'Ackee', 'Onion', 'Paprika', 'Cur...

# %%
aldi_db
# Out:
#      Unnamed: 0                                         Ingredient  Price
# 0             1   Rich & Creamy Melt In The Middle Salmon Fishc...   2.79
# 1             2   Smoked Mackerel Fillets - Peppered 200g The F...   1.49
# 2             3   Smoked Mackerel Fillets - Hot 200g The Fishmo...   1.49
# 3             4     Hot Smoked Salmon Fillets 185g The Fishmonger    3.49
# 4             5                               Salmon Fillets 185g    3.49
# ..          ...                                                ...    ...
# 743          38          Granny Smith Apples 6 Pack Nature's Pick    1.29
# 744          39   Spinach & Rocket / Spinach & Kale 120g Health...   1.29
# 745          40   Spinach & Rocket / Spinach & Kale 120g Health...   1.29
# 746          41                         Strawberries 250g Organic    2.49
# 747          42            Prepared Vegetables 500g Nature's Pick    1.25
#
# [748 rows x 3 columns]
