# %%
import pandas as pd

# %%
aldi_db = pd.read_csv('aldi_db.csv')
aldi_db
# Out:
#      Unnamed: 0                                         Ingredient  Price
# 0             1   Rich & Creamy Melt In The Middle Salmon Fishc...   2.79
# 1             2   Smoked Mackerel Fillets - Peppered 200g The F...   1.49
# 2             3   Smoked Mackerel Fillets - Hot 200g The Fishmo...   1.49
# 3             4     Hot Smoked Salmon Fillets 185g The Fishmonger    3.49
# 4             5                               Salmon Fillets 185g    3.49
# ..          ...                                                ...    ...
# 743          38          Granny Smith Apples 6 Pack Nature's Pick    1.29
# 744          39   Spinach & Rocket / Spinach & Kale 120g Health...   1.29
# 745          40   Spinach & Rocket / Spinach & Kale 120g Health...   1.29
# 746          41                         Strawberries 250g Organic    2.49
# 747          42            Prepared Vegetables 500g Nature's Pick    1.25
#
# [748 rows x 3 columns]

# %%
pd.set_option('max_row', None)

print(test)
# Out:
#      Unnamed: 0                                         Ingredient  Price
# 0             1   Rich & Creamy Melt In The Middle Salmon Fishc...   2.79
# 1             2   Smoked Mackerel Fillets - Peppered 200g The F...   1.49
# 2             3   Smoked Mackerel Fillets - Hot 200g The Fishmo...   1.49
# 3             4     Hot Smoked Salmon Fillets 185g The Fishmonger    3.49
# 4             5                               Salmon Fillets 185g    3.49
# 5             6   Smoked Mackerel Fillets - Piri Piri 200g The ...   1.49
# 6             7   Rich & Creamy Seafood Chowder 375g Specially ...   3.29
# 7             8   Organic  Salmon Fillets 240g Specially Selected    5.99
# 8             9          Smoked Salmon Slices 200g The Fishmonger    2.99
# 9            10   Organic  Cold Smoked Salmon 100g Specially Se...   3.69
# 10           11                 4 Salmon Fillets 440g Skellig Bay    6.49
# 11           12           Fresh Half Side Salmon 450g Skellig Bay    7.29
# ...

# %%
prices3=[1,2,3]

# %%
products3=['a','b','c']

# %%
pd.DataFrame(zip(prices3, products3), columns=['products:','price:'])
# Out:
#    products: prices
# 0          1      a
# 1          2      b
# 2          3      c

# %%
v = pd.read_csv('veggie_db')

# %%
v
# Out:
#    Unnamed: 0     id                                         ings  \
# 0           0  52908                     [720, 731, 81, 709, 713]
# 1           1  52849  [462, 420, 121, 51, 709, 308, 81, 373, 731]
# 2           2  52869               [727, 713, 720, 322, 323, 389]
# 3           3  52863      [323, 709, 708, 715, 731, 713, 115, 89]
# 4           4  52867                           [747, 34, 87, 709]
# 5           5  53047                    [265, 708, 340, 715, 727]
# 6           6  52771                  [116, 70, 81, 85, 715, 744]
# 7           7  53026                          [208, 316, 428, 51]
# 8           8  52906                         [427, 428, 349, 377]
# 9           9  52811                [429, 731, 242, 744, 89, 421]
#
#                            name  \
# 0                   Ratatouille
# 1  Spinach & Ricotta Cannelloni
# 2                Tahini Lentils
# 3          Vegetarian Casserole
# 4             Vegetarian Chilli
# 5          Moroccan Carrot Soup
# ...
